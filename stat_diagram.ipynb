# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/Dell/Documents/book/unsuper/Projects/first/mental-heath-in-tech-2016_20161114.csv')

df_stat = df.copy()
# Recode Comp size & country columns (for ease when doing plots)
df_stat['How many employees does your company or organization have?'].replace(to_replace = ['More than 1000'], value = '>1000', inplace = True)
df_stat['What country do you work in?'].replace(to_replace = ['United States of America'], value = 'USA', inplace = True)
df_stat['What country do you work in?'].replace(to_replace = ['United Kingdom'], value = 'UK', inplace = True)

# %%
df_stat = df_stat[df_stat['What country do you work in?'].isin(['USA','UK','Canada', 'Germany', 'Netherlands','Australia'])]
plt.rcParams['xtick.labelsize'] = 7
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
plt.figure(figsize = (16,4))
fig.set_figheight(2)
fig.set_figwidth(10)
plt.subplots_adjust(wspace = 0)
# plt.suptitle('Main Title')
# No of respondents by Country
sns.countplot(x = df_stat['What country do you work in?'], hue = df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'], ax=ax1)
ax1.set_title('No. of Respondents by Country and sought treatment', fontsize = 6)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha="right")
ax1.set_xlabel('Country', fontsize = 6)
ax1.set_ylabel('Count', fontsize = 6)
ax1.legend(['Not sought treatment', 'sought treatment'],fontsize = 6)
# No of respondents by Company Size
sns.countplot(x = df_stat['How many employees does your company or organization have?'], hue = df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'], ax=ax2, 
              order = ['1-5', '6-25', '26-100', '100-500', '500-1000', '>1000'])
ax2.set_title('No. of Respondents by Company and sought treatment', fontsize = 6)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=15, ha="right")
ax2.set_xlabel('Company Size', fontsize = 6)
ax2.set_ylabel('Count', fontsize = 6)
ax2.legend(['Not sought treatment', 'sought treatment'],fontsize = 6);
fig.savefig('C:/Users/Dell/Documents/book/unsuper/send for github/output.png')

# %%
fig, (ax1, ax2) = plt.subplots(figsize = (16, 4), ncols=2, nrows=1)
plt.subplots_adjust(left=0.125, right=0.9, bottom=0.1, top = 0.9, wspace=0, hspace = 0.3)
#plt.suptitle('bring up a mental health issue with a potential employer in an interview?', fontsize = 23, y = 1.1)

# Do you feel that being identified as a person with a mental health issue would hurt your career?
all_ = df_stat[df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1]['Have you ever sought treatment for a mental health issue from a mental health professional?'].count()

Maybe = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat['Would you bring up a mental health issue with a potential employer in an interview?'] == "Maybe")]['Would you bring up a mental health issue with a potential employer in an interview?'].count()
No = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat['Would you bring up a mental health issue with a potential employer in an interview?'] == "No")]['Would you bring up a mental health issue with a potential employer in an interview?'].count()
Yes = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat['Would you bring up a mental health issue with a potential employer in an interview?'] == 'Yes')]['Would you bring up a mental health issue with a potential employer in an interview?'].count()

labels = 'Maybe', 'No', 'Yes'
sizes = [Maybe, No, Yes]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A']
#explode = (0, 0, 0.03)  # explode 1st slice

ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax1.axis('equal')
ax1.set_title('Would you bring up a mental health issue with a potential employer in an interview?', pad = 14, fontsize = 10)



#####################
#'If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?
all_ = df_stat[df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1]['Have you ever sought treatment for a mental health issue from a mental health professional?'].count()

Rarely = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1) & (df_stat['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'] == 'Rarely')]['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'].count()
Sometimes = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1) & (df_stat['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'] == 'Sometimes')]['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'].count()

Often = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1) & (df_stat['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'] == 'Often')]['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'].count()

Never = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1) & (df_stat['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'] == 'Never')]['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'].count()

Not_applicable_to_me = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1) & (df_stat['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'] == "Not applicable to me")]['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'].count()


labels = 'Not applicable to me', 'Rarely', 'Sometimes', 'Often','Never'
sizes = [Not_applicable_to_me, Rarely, Sometimes, Often, Never]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A', '#C39BD3', '#ABEBC6']
#explode = (0.03, 0, 0, 0)  # explode 1st slice

ax2.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax2.axis('equal')
ax2.set_title('Do you feel that mental health interferes with your work when being treated effectively?', pad = 14, fontsize = 10);

fig.savefig('C:/Users/Dell/Documents/book/unsuper/send for github/second.png')

# %%
fig, (ax1, ax2) = plt.subplots(figsize = (16, 4), ncols=2, nrows=1)
plt.subplots_adjust(left=0.125, right=0.9, bottom=0.1, top = 0.9, wspace=0, hspace = 0.3)
#plt.suptitle('bring up a mental health issue with a potential employer in an interview?', fontsize = 23, y = 1.1)

# Do you feel that being identified as a person with a mental health issue would hurt your career?
all_ = df_stat[df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1]['Have you ever sought treatment for a mental health issue from a mental health professional?'].count()

Maybe = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat['Do you currently have a mental health disorder?'] == "Maybe")]['Do you currently have a mental health disorder?'].count()
No = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat['Do you currently have a mental health disorder?'] == "No")]['Do you currently have a mental health disorder?'].count()
Yes = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat['Do you currently have a mental health disorder?'] == 'Yes')]['Do you currently have a mental health disorder?'].count()

labels = 'Maybe', 'No', 'Yes'
sizes = [Maybe, No, Yes]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A']
#explode = (0, 0, 0.03)  # explode 1st slice

ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax1.axis('equal')
ax1.set_title('Do you currently have a mental health disorder?', pad = 14, fontsize = 10)



#####################
#'If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?
all_ = df_stat[df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1]['Have you ever sought treatment for a mental health issue from a mental health professional?'].count()

Yes = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1) & (df_stat['Have you had a mental health disorder in the past?'] == 'Yes')]['Have you had a mental health disorder in the past?'].count()

Maybe = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1) & (df_stat['Have you had a mental health disorder in the past?'] == 'Maybe')]['Have you had a mental health disorder in the past?'].count()

No = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)& (df_stat['Have you had a mental health disorder in the past?'] == "No")]['Have you had a mental health disorder in the past?'].count()

labels = 'Maybe', 'No', 'Yes'
sizes = [Maybe, No, Yes]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A']

#explode = (0.03, 0, 0, 0)  # explode 1st slice

ax2.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax2.axis('equal')
ax2.set_title('Have you had a mental health disorder in the past?', pad = 14, fontsize = 12);

fig.savefig('C:/Users/Dell/Documents/book/unsuper/send for github/third.png')

# %%
stext = 'Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?'
fig, (ax1, ax2) = plt.subplots(figsize = (16, 4), ncols=2, nrows=1)

plt.subplots_adjust(left=0.125, right=0.9, bottom=0.1, top = 0.9, wspace=0, hspace = 0.3)
#plt.suptitle('bring up a mental health issue with a potential employer in an interview?', fontsize = 23, y = 1.1)

# Do you feel that being identified as a person with a mental health issue would hurt your career?
all_ = df_stat[df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1]['Have you ever sought treatment for a mental health issue from a mental health professional?'].count()

No_I_do_not_think_they_would = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == "No, I don't think they would")][stext].count()

Maybe = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == "Maybe")][stext].count()

Yes_they_do = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == 'Yes, they do')][stext].count()

Yes_I_think_they_would = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == 'Yes, I think they would')][stext].count()

No_they_do_not = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == 'No, they do not')][stext].count()

labels = "No, I don't think they would", 'Maybe','Yes they do','Yes I think they would','No, they do not'
sizes = [No_I_do_not_think_they_would, Maybe, Yes_they_do,Yes_I_think_they_would,No_they_do_not]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A', '#C39BD3', '#ABEBC6']

#explode = (0, 0, 0.03)  # explode 1st slice

ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax1.axis('equal')
ax1.set_title('Team members would view you more negatively if they knew you suffered from a mental health issue?', pad = 13, fontsize = 9)


#####################
ttext = 'Have you been diagnosed with a mental health condition by a medical professional?'
all_ = df_stat[df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1]['Have you ever sought treatment for a mental health issue from a mental health professional?'].count()

Yes = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1) & 
(df_stat[ttext] == 'Yes')][ttext].count()


No = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)& 
(df_stat[ttext] == "No")][ttext].count()

labels = 'No', 'Yes'
sizes = [No, Yes]
colors = ['#73C6B6', '#F0B27A']

#explode = (0.03, 0, 0, 0)  # explode 1st slice

ax2.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax2.axis('equal')
ax2.set_title('Have you been diagnosed with a mental health condition by a medical professional?', pad = 14, fontsize = 10);

fig.savefig('C:/Users/Dell/Documents/book/unsuper/send for github/forth.png')

# %%
plt.figure(figsize = (16, 5))


all_ = df_stat[df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1]['Have you ever sought treatment for a mental health issue from a mental health professional?'].count()
No_I_do_not_think_they_would = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == "No, I don't think they would")][stext].count()
Maybe = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == "Maybe")][stext].count()
Yes_they_do = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == 'Yes, they do')][stext].count()
Yes_I_think_they_would = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == 'Yes, I think they would')][stext].count()
No_they_do_not = df_stat[(df_stat['Have you ever sought treatment for a mental health issue from a mental health professional?'] == 1)
& (df_stat[stext] == 'No, they do not')][stext].count()
labels = "No, I don't think they would", 'Maybe','Yes they do','Yes I think they would','No, they do not'
sizes = [No_I_do_not_think_they_would, Maybe, Yes_they_do,Yes_I_think_they_would,No_they_do_not]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A', '#C39BD3', '#ABEBC6']
explode = (0, 0, 0, 0.05, 0.05)  # explode 1st slice


plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
plt.axis('equal')
plt.title('Team members would view you more negatively if they knew you suffered from a mental health issue?', pad = 14, fontsize = 14);
plt.savefig('C:/Users/Dell/Documents/book/unsuper/send for github/fifth.png')
